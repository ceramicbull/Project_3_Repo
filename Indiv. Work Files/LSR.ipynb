# %%
import numpy as np

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import pandas as pd
import datetime as dt

# %%
engine = create_engine("sqlite:///ufo.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(autoload_with=engine)

# Save reference to the table
Ufos = Base.classes.ufo_sightings

# %%
# Open session
session = Session(engine)

# %%
session.query(Ufos.state, Ufos.date_time).all()
# Out:
# [('AL', datetime.datetime(2023, 5, 14, 21, 55)),
#  ('AL', datetime.datetime(2023, 5, 14, 20, 40)),
#  ('AL', datetime.datetime(2023, 5, 13, 21, 30)),
#  ('AL', datetime.datetime(2023, 5, 2, 4, 46)),
#  ('AL', datetime.datetime(2023, 5, 1, 3, 32)),
#  ('AL', datetime.datetime(2023, 4, 14, 5, 7)),
#  ('AL', datetime.datetime(2023, 4, 2, 15, 0)),
#  ('AL', datetime.datetime(2023, 3, 27, 19, 0)),
#  ('AL', datetime.datetime(2023, 3, 17, 23, 30)),
#  ('AL', datetime.datetime(2023, 3, 14, 20, 30)),
#  ('AL', datetime.datetime(2023, 3, 14, 3, 0)),
#  ('AL', datetime.datetime(2023, 3, 9, 19, 37)),
#  ('AL', datetime.datetime(2023, 2, 27, 19, 0)),
#  ('AL', datetime.datetime(2023, 2, 21, 19, 58)),
#  ('AL', datetime.datetime(2023, 2, 15, 3, 12)),
#  ('AL', datetime.datetime(2023, 2, 13, 22, 15)),
#  ('AL', datetime.datetime(2023, 2, 12, 18, 35)),
#  ('AL', datetime.datetime(2023, 2, 12, 18, 35)),
#  ('AL', datetime.datetime(2023, 2, 9, 3, 45)),
#  ('AL', datetime.datetime(2023, 1, 20, 17, 14)),
#  ('AL', datetime.datetime(2023, 1, 18, 13, 15)),
#  ('AL', datetime.datetime(2023, 1, 18, 0, 42)),
#  ('AL', datetime.datetime(2023, 1, 7, 18, 0)),
#  ('AL', datetime.datetime(2023, 1, 4, 21, 51)),
#  ('AL', datetime.datetime(2023, 1, 1, 22, 0)),
#  ('AL', datetime.datetime(2022, 12, 31, 19, 2)),
#  ('AL', datetime.datetime(2022, 12, 16, 15, 29)),
#  ('AL', datetime.datetime(2022, 12, 15, 1, 30)),
#  ('AL', datetime.datetime(2022, 12, 12, 6, 56)),
#  ('AL', datetime.datetime(2022, 12, 7, 17, 48)),
#  ('AL', datetime.datetime(2022, 11, 17, 22, 2)),
#  ('AL', datetime.datetime(2022, 11, 8, 20, 6)),
#  ('AL', datetime.datetime(2022, 11, 8, 17, 0)),
#  ('AL', datetime.datetime(2022, 11, 6, 11, 59)),
#  ('AL', datetime.datetime(2022, 10, 28, 3, 0)),
#  ('AL', datetime.datetime(2022, 10, 27, 20, 34)),
#  ('AL', datetime.datetime(2022, 10, 26, 6, 55)),
#  ('AL', datetime.datetime(2022, 10, 25, 20, 11)),
#  ('AL', datetime.datetime(2022, 10, 20, 19, 30)),
#  ('AL', datetime.datetime(2022, 10, 19, 19, 0)),
#  ('AL', datetime.datetime(2022, 10, 18, 12, 30)),
#  ('AL', datetime.datetime(2022, 10, 6, 19, 0)),
#  ('AL', datetime.datetime(2022, 10, 1, 18, 40)),
#  ('AL', datetime.datetime(2022, 10, 1, 15, 34)),
#  ('AL', datetime.datetime(2022, 9, 24, 21, 15)),
#  ('AL', datetime.datetime(2022, 9, 21, 23, 28)),
#  ('AL', datetime.datetime(2022, 9, 21, 22, 45)),
#  ('AL', datetime.datetime(2022, 9, 19, 19, 31)),
#  ('AL', datetime.datetime(2022, 9, 14, 20, 0)),
#  ('AL', datetime.datetime(2022, 9, 11, 0, 30)),
#  ('AL', datetime.datetime(2022, 9, 8, 21, 0)),
#  ('AL', datetime.datetime(2022, 9, 7, 19, 45)),
#  ('AL', datetime.datetime(2022, 9, 5, 5, 13)),
#  ('AL', datetime.datetime(2022, 8, 31, 21, 2)),
#  ('AL', datetime.datetime(2022, 8, 27, 22, 0)),
#  ('AL', datetime.datetime(2022, 8, 10, 19, 30)),
#  ('AL', datetime.datetime(2022, 8, 7, 21, 25)),
#  ('AL', datetime.datetime(2022, 7, 29, 4, 50)),
#  ('AL', datetime.datetime(2022, 6, 19, 1, 20)),
#  ('AL', datetime.datetime(2022, 6, 14, 20, 35)),
#  ('AL', datetime.datetime(2022, 6, 11, 13, 42)),
#  ('AL', datetime.datetime(2022, 6, 10, 8, 28)),
#  ('AL', datetime.datetime(2022, 6, 6, 21, 30)),
#  ('AL', datetime.datetime(2022, 6, 5, 2, 0)),
#  ('AL', datetime.datetime(2022, 6, 4, 15, 45)),
#  ('AL', datetime.datetime(2022, 6, 4, 3, 38)),
#  ('AL', datetime.datetime(2022, 6, 1, 3, 40)),
#  ('AL', datetime.datetime(2022, 5, 28, 13, 44)),
#  ('AL', datetime.datetime(2022, 5, 20, 6, 50)),
#  ('AL', datetime.datetime(2022, 5, 17, 22, 54)),
#  ('AL', datetime.datetime(2022, 5, 17, 20, 24)),
#  ('AL', datetime.datetime(2022, 5, 13, 12, 18)),
#  ('AL', datetime.datetime(2022, 5, 13, 1, 0)),
#  ('AL', datetime.datetime(2022, 5, 7, 11, 38)),
#  ('AL', datetime.datetime(2022, 5, 4, 2, 12)),
#  ('AL', datetime.datetime(2022, 5, 2, 1, 0)),
#  ('AL', datetime.datetime(2022, 4, 24, 10, 31)),
#  ('AL', datetime.datetime(2022, 4, 11, 1, 42)),
#  ('AL', datetime.datetime(2022, 3, 24, 2, 44)),
#  ('AL', datetime.datetime(2022, 3, 23, 14, 55)),
#  ('AL', datetime.datetime(2022, 3, 23, 5, 32)),
#  ('AL', datetime.datetime(2022, 3, 22, 10, 46)),
#  ('AL', datetime.datetime(2022, 3, 19, 20, 30)),
#  ('AL', datetime.datetime(2022, 3, 17, 13, 56)),
#  ('AL', datetime.datetime(2022, 3, 11, 22, 30)),
#  ('AL', datetime.datetime(2022, 3, 1, 17, 0)),
#  ('AL', datetime.datetime(2022, 3, 1, 0, 0)),
#  ('AL', datetime.datetime(2022, 2, 27, 16, 34)),
#  ('AL', datetime.datetime(2022, 2, 25, 11, 54)),
#  ('AL', datetime.datetime(2022, 2, 24, 18, 0)),
#  ('AL', datetime.datetime(2022, 2, 13, 0, 38)),
#  ('AL', datetime.datetime(2022, 2, 3, 0, 25)),
#  ('AL', datetime.datetime(2022, 2, 2, 15, 45)),
#  ('AL', datetime.datetime(2022, 1, 29, 19, 0)),
#  ('AL', datetime.datetime(2022, 1, 28, 13, 52)),
#  ('AL', datetime.datetime(2022, 1, 27, 19, 0)),
#  ('AL', datetime.datetime(2022, 1, 26, 19, 30)),
#  ('AL', datetime.datetime(2022, 1, 26, 6, 34)),
#  ('AL', datetime.datetime(2022, 1, 19, 0, 0)),
#  ('AL', datetime.datetime(2022, 1, 18, 17, 49)),
#  ('AL', datetime.datetime(2022, 1, 11, 13, 15)),
#  ('AL', datetime.datetime(2021, 12, 30, 16, 55)),
#  ('AL', datetime.datetime(2021, 12, 29, 6, 57)),
#  ('AL', datetime.datetime(2021, 12, 11, 18, 45)),
#  ('AL', datetime.datetime(2021, 12, 3, 18, 30)),
#  ('AL', datetime.datetime(2021, 12, 3, 18, 0)),
#  ('AL', datetime.datetime(2021, 11, 22, 4, 26)),
#  ('AL', datetime.datetime(2021, 10, 21, 19, 0)),
#  ('AL', datetime.datetime(2021, 10, 15, 20, 0)),
#  ('AL', datetime.datetime(2021, 10, 10, 19, 13)),
#  ('AL', datetime.datetime(2021, 10, 8, 22, 0)),
#  ('AL', datetime.datetime(2021, 7, 5, 7, 45)),
#  ('AL', datetime.datetime(2021, 5, 21, 20, 45)),
#  ('AL', datetime.datetime(2021, 5, 16, 9, 54)),
#  ('AL', datetime.datetime(2021, 5, 9, 23, 30)),
#  ('AL', datetime.datetime(2021, 4, 27, 10, 22)),
#  ('AL', datetime.datetime(2021, 4, 11, 20, 35)),
#  ('AL', datetime.datetime(2021, 3, 18, 22, 0)),
#  ('AL', datetime.datetime(2021, 3, 5, 23, 0)),
#  ('AL', datetime.datetime(2021, 2, 20, 10, 15)),
#  ('AL', datetime.datetime(2021, 2, 13, 19, 53)),
#  ('AL', datetime.datetime(2021, 2, 9, 19, 30)),
#  ('AL', datetime.datetime(2020, 12, 26, 18, 20)),
#  ('AL', datetime.datetime(2020, 12, 1, 17, 50)),
#  ('AL', datetime.datetime(2020, 11, 30, 0, 40)),
#  ('AL', datetime.datetime(2020, 11, 7, 0, 0)),
#  ('AL', datetime.datetime(2020, 10, 16, 21, 35)),
#  ('AL', datetime.datetime(2020, 10, 13, 20, 30)),
#  ('AL', datetime.datetime(2020, 10, 8, 5, 20)),
#  ('AL', datetime.datetime(2020, 10, 1, 5, 0)),
#  ('AL', datetime.datetime(2020, 9, 28, 15, 0)),
#  ('AL', datetime.datetime(2020, 9, 26, 0, 34)),
#  ('AL', datetime.datetime(2020, 9, 11, 20, 20)),
#  ('AL', datetime.datetime(2020, 9, 4, 21, 30)),
#  ('AL', datetime.datetime(2020, 8, 19, 22, 0)),
#  ('AL', datetime.datetime(2020, 8, 19, 16, 15)),
#  ('AL', datetime.datetime(2020, 8, 18, 22, 0)),
#  ('AL', datetime.datetime(2020, 8, 14, 13, 30)),
#  ('AL', datetime.datetime(2020, 8, 8, 13, 0)),
#  ('AL', datetime.datetime(2020, 8, 2, 1, 45)),
#  ('AL', datetime.datetime(2020, 8, 1, 22, 50)),
#  ('AL', datetime.datetime(2020, 7, 31, 23, 0)),
#  ('AL', datetime.datetime(2020, 7, 26, 19, 45)),
#  ('AL', datetime.datetime(2020, 7, 21, 8, 45)),
#  ('AL', datetime.datetime(2020, 7, 15, 2, 0)),
#  ('AL', datetime.datetime(2020, 7, 10, 22, 0)),
#  ('AL', datetime.datetime(2020, 7, 4, 21, 30)),
#  ('AL', datetime.datetime(2020, 7, 4, 20, 0)),
#  ('AL', datetime.datetime(2020, 7, 2, 21, 30)),
#  ('AL', datetime.datetime(2020, 6, 18, 3, 0)),
#  ('AL', datetime.datetime(2020, 6, 11, 12, 0)),
#  ('AL', datetime.datetime(2020, 6, 10, 19, 0)),
#  ('AL', datetime.datetime(2020, 5, 25, 21, 0)),
#  ('AL', datetime.datetime(2020, 5, 13, 23, 50)),
#  ('AL', datetime.datetime(2020, 4, 30, 22, 0)),
#  ('AL', datetime.datetime(2020, 4, 29, 21, 0)),
#  ('AL', datetime.datetime(2020, 4, 25, 10, 30)),
#  ('AL', datetime.datetime(2020, 4, 20, 11, 15)),
#  ('AL', datetime.datetime(2020, 4, 15, 0, 0)),
#  ('AL', datetime.datetime(2020, 4, 14, 10, 30)),
#  ('AL', datetime.datetime(2020, 4, 13, 21, 15)),
#  ('AL', datetime.datetime(2020, 4, 12, 12, 0)),
#  ('AL', datetime.datetime(2020, 4, 11, 21, 5)),
#  ('AL', datetime.datetime(2020, 4, 10, 0, 0)),
#  ('AL', datetime.datetime(2020, 4, 9, 5, 0)),
#  ('AL', datetime.datetime(2020, 4, 7, 18, 0)),
#  ('AL', datetime.datetime(2020, 3, 29, 11, 0)),
#  ('AL', datetime.datetime(2020, 3, 25, 22, 6)),
#  ('AL', datetime.datetime(2020, 2, 19, 15, 50)),
#  ('AL', datetime.datetime(2020, 2, 6, 18, 26)),
#  ('AL', datetime.datetime(2020, 2, 3, 23, 16)),
#  ('AL', datetime.datetime(2020, 2, 3, 20, 0)),
#  ('AL', datetime.datetime(2020, 2, 2, 19, 0)),
#  ('AL', datetime.datetime(2020, 2, 2, 15, 30)),
#  ('AL', datetime.datetime(2020, 2, 2, 7, 30)),
#  ('AL', datetime.datetime(2020, 2, 1, 7, 0)),
#  ('AL', datetime.datetime(2020, 1, 26, 4, 13)),
#  ('AL', datetime.datetime(2020, 1, 22, 16, 45)),
#  ('AL', datetime.datetime(2020, 1, 21, 16, 28)),
#  ('AL', datetime.datetime(2020, 1, 15, 22, 0)),
#  ('AL', datetime.datetime(2020, 1, 10, 4, 49)),
#  ('AL', datetime.datetime(2020, 1, 8, 18, 0)),
#  ('AL', datetime.datetime(2020, 1, 7, 6, 53)),
#  ('AL', datetime.datetime(2020, 1, 6, 16, 25)),
#  ('AL', datetime.datetime(2020, 1, 5, 12, 5)),
#  ('AL', datetime.datetime(2019, 12, 30, 22, 20)),
#  ('AL', datetime.datetime(2019, 12, 30, 12, 0)),
#  ('AL', datetime.datetime(2019, 12, 29, 18, 26)),
#  ('AL', datetime.datetime(2019, 12, 27, 19, 0)),
#  ('AL', datetime.datetime(2019, 12, 26, 0, 25)),
#  ('AL', datetime.datetime(2019, 12, 25, 17, 40)),
#  ('AL', datetime.datetime(2019, 12, 19, 17, 39)),
#  ('AL', datetime.datetime(2019, 12, 18, 18, 20)),
#  ('AL', datetime.datetime(2019, 12, 18, 8, 30)),
#  ('AL', datetime.datetime(2019, 12, 11, 19, 25)),
#  ('AL', datetime.datetime(2019, 11, 30, 4, 45)),
#  ('AL', datetime.datetime(2019, 11, 21, 18, 5)),
#  ('AL', datetime.datetime(2019, 11, 19, 19, 30)),
#  ('AL', datetime.datetime(2019, 11, 10, 17, 0)),
#  ('AL', datetime.datetime(2019, 11, 10, 16, 26)),
#  ('AL', datetime.datetime(2019, 10, 24, 23, 0)),
#  ('AL', datetime.datetime(2019, 10, 19, 20, 0)),
#  ('AL', datetime.datetime(2019, 10, 11, 20, 0)),
#  ('AL', datetime.datetime(2019, 10, 10, 17, 0)),
#  ('AL', datetime.datetime(2019, 10, 7, 4, 0)),
#  ('AL', datetime.datetime(2019, 10, 6, 3, 0)),
#  ('AL', datetime.datetime(2019, 10, 3, 9, 23)),
#  ('AL', datetime.datetime(2019, 10, 1, 19, 0)),
#  ('AL', datetime.datetime(2019, 9, 29, 20, 0)),
#  ('AL', datetime.datetime(2019, 9, 28, 9, 30)),
#  ('AL', datetime.datetime(2019, 9, 25, 8, 45)),
#  ('AL', datetime.datetime(2019, 9, 24, 21, 30)),
#  ('AL', datetime.datetime(2019, 9, 18, 18, 40)),
#  ('AL', datetime.datetime(2019, 8, 29, 14, 49)),
#  ('AL', datetime.datetime(2019, 8, 16, 8, 0)),
#  ('AL', datetime.datetime(2019, 8, 5, 16, 0)),
#  ('AL', datetime.datetime(2019, 8, 4, 22, 0)),
#  ('AL', datetime.datetime(2019, 7, 20, 22, 0)),
#  ('AL', datetime.datetime(2019, 7, 18, 20, 30)),
#  ('AL', datetime.datetime(2019, 7, 17, 4, 5)),
#  ('AL', datetime.datetime(2019, 7, 8, 22, 24)),
#  ('AL', datetime.datetime(2019, 7, 4, 21, 0)),
#  ('AL', datetime.datetime(2019, 7, 4, 21, 0)),
#  ('AL', datetime.datetime(2019, 6, 30, 1, 30)),
#  ('AL', datetime.datetime(2019, 6, 15, 21, 11)),
#  ('AL', datetime.datetime(2019, 6, 13, 20, 45)),
#  ('AL', datetime.datetime(2019, 6, 8, 23, 30)),
#  ('AL', datetime.datetime(2019, 5, 26, 0, 0)),
#  ('AL', datetime.datetime(2019, 5, 25, 1, 15)),
#  ('AL', datetime.datetime(2019, 5, 24, 0, 14)),
#  ('AL', datetime.datetime(2019, 5, 21, 22, 0)),
#  ('AL', datetime.datetime(2019, 5, 20, 23, 0)),
#  ('AL', datetime.datetime(2019, 5, 8, 18, 0)),
#  ('AL', datetime.datetime(2019, 5, 6, 1, 0)),
#  ('AL', datetime.datetime(2019, 4, 26, 22, 0)),
#  ('AL', datetime.datetime(2019, 4, 21, 21, 15)),
#  ('AL', datetime.datetime(2019, 4, 4, 5, 55)),
#  ('AL', datetime.datetime(2019, 3, 30, 23, 0)),
#  ('AL', datetime.datetime(2019, 3, 24, 16, 0)),
#  ('AL', datetime.datetime(2019, 3, 22, 20, 5)),
#  ('AL', datetime.datetime(2019, 3, 20, 23, 30)),
#  ('AL', datetime.datetime(2019, 2, 25, 23, 45)),
#  ('AL', datetime.datetime(2019, 2, 21, 12, 0)),
#  ('AL', datetime.datetime(2019, 2, 21, 3, 0)),
#  ('AL', datetime.datetime(2019, 2, 18, 21, 15)),
#  ('AL', datetime.datetime(2019, 1, 15, 1, 20)),
#  ('AL', datetime.datetime(2019, 1, 2, 10, 0)),
#  ('AL', datetime.datetime(2018, 11, 18, 18, 0)),
#  ('AL', datetime.datetime(2018, 10, 31, 20, 0)),
#  ('AL', datetime.datetime(2018, 10, 18, 22, 0)),
#  ('AL', datetime.datetime(2018, 10, 18, 21, 0)),
#  ('AL', datetime.datetime(2018, 10, 1, 0, 0)),
#  ('AL', datetime.datetime(2018, 9, 30, 23, 30)),
#  ('AL', datetime.datetime(2018, 9, 24, 8, 30)),
#  ('AL', datetime.datetime(2018, 9, 13, 23, 32)),
#  ('AL', datetime.datetime(2018, 8, 14, 23, 0)),
#  ('AL', datetime.datetime(2018, 8, 2, 23, 30)),
#  ('AL', datetime.datetime(2018, 7, 29, 17, 15)),
#  ('AL', datetime.datetime(2018, 7, 22, 18, 0)),
#  ('AL', datetime.datetime(2018, 7, 20, 21, 0)),
#  ('AL', datetime.datetime(2018, 7, 19, 10, 30)),
#  ('AL', datetime.datetime(2018, 7, 18, 22, 0)),
#  ('AL', datetime.datetime(2018, 7, 18, 21, 30)),
#  ('AL', datetime.datetime(2018, 7, 17, 22, 40)),
#  ('AL', datetime.datetime(2018, 7, 16, 23, 0)),
#  ('AL', datetime.datetime(2018, 6, 25, 20, 15)),
#  ('AL', datetime.datetime(2018, 6, 22, 18, 0)),
#  ('AL', datetime.datetime(2018, 6, 21, 4, 30)),
#  ('AL', datetime.datetime(2018, 6, 6, 22, 30)),
#  ('AL', datetime.datetime(2018, 5, 31, 22, 10)),
#  ('AL', datetime.datetime(2018, 4, 25, 2, 0)),
#  ('AL', datetime.datetime(2018, 4, 24, 20, 30)),
#  ('AL', datetime.datetime(2018, 4, 11, 17, 40)),
#  ('AL', datetime.datetime(2018, 4, 4, 21, 0)),
#  ('AL', datetime.datetime(2018, 3, 22, 7, 18)),
#  ('AL', datetime.datetime(2018, 3, 4, 20, 45)),
#  ('AL', datetime.datetime(2018, 2, 21, 21, 37)),
#  ('AL', datetime.datetime(2018, 2, 13, 19, 0)),
#  ('AL', datetime.datetime(2017, 12, 26, 20, 30)),
#  ('AL', datetime.datetime(2017, 12, 14, 3, 47)),
#  ('AL', datetime.datetime(2017, 12, 13, 17, 30)),
#  ('AL', datetime.datetime(2017, 12, 10, 0, 0)),
#  ('AL', datetime.datetime(2017, 11, 27, 18, 0)),
#  ('AL', datetime.datetime(2017, 11, 27, 11, 20)),
#  ('AL', datetime.datetime(2017, 11, 26, 17, 35)),
#  ('AL', datetime.datetime(2017, 11, 14, 21, 0)),
#  ('AL', datetime.datetime(2017, 11, 13, 23, 0)),
#  ('AL', datetime.datetime(2017, 11, 13, 21, 0)),
#  ('AL', datetime.datetime(2017, 11, 9, 15, 0)),
#  ('AL', datetime.datetime(2017, 11, 6, 17, 5)),
#  ('AL', datetime.datetime(2017, 10, 30, 19, 0)),
#  ('AL', datetime.datetime(2017, 10, 24, 5, 15)),
#  ('AL', datetime.datetime(2017, 10, 22, 18, 0)),
#  ('AL', datetime.datetime(2017, 10, 20, 18, 30)),
#  ('AL', datetime.datetime(2017, 10, 20, 11, 0)),
#  ('AL', datetime.datetime(2017, 10, 18, 19, 16)),
#  ('AL', datetime.datetime(2017, 10, 18, 11, 0)),
#  ('AL', datetime.datetime(2017, 10, 17, 19, 30)),
#  ('AL', datetime.datetime(2017, 10, 17, 0, 0)),
#  ('AL', datetime.datetime(2017, 10, 2, 20, 30)),
#  ('AL', datetime.datetime(2017, 9, 15, 19, 0)),
#  ('AL', datetime.datetime(2017, 9, 10, 20, 0)),
#  ('AL', datetime.datetime(2017, 8, 16, 16, 0)),
#  ('AL', datetime.datetime(2017, 8, 15, 17, 0)),
#  ('AL', datetime.datetime(2017, 8, 8, 21, 15)),
#  ('AL', datetime.datetime(2017, 8, 8, 20, 30)),
#  ('AL', datetime.datetime(2017, 7, 20, 21, 48)),
#  ('AL', datetime.datetime(2017, 7, 11, 14, 0)),
#  ('AL', datetime.datetime(2017, 6, 30, 21, 45)),
#  ('AL', datetime.datetime(2017, 6, 24, 21, 0)),
#  ('AL', datetime.datetime(2017, 5, 30, 21, 15)),
#  ('AL', datetime.datetime(2017, 5, 16, 9, 50)),
#  ('AL', datetime.datetime(2017, 5, 9, 3, 30)),
#  ('AL', datetime.datetime(2017, 5, 7, 20, 0)),
#  ('AL', datetime.datetime(2017, 5, 7, 19, 30)),
#  ('AL', datetime.datetime(2017, 4, 29, 15, 0)),
#  ('AL', datetime.datetime(2017, 4, 23, 19, 0)),
#  ('AL', datetime.datetime(2017, 4, 19, 23, 55)),
#  ('AL', datetime.datetime(2017, 4, 19, 23, 50)),
#  ('AL', datetime.datetime(2017, 4, 17, 3, 58)),
#  ('AL', datetime.datetime(2017, 4, 15, 22, 10)),
#  ('AL', datetime.datetime(2017, 4, 15, 20, 0)),
#  ('AL', datetime.datetime(2017, 4, 14, 22, 0)),
#  ('AL', datetime.datetime(2017, 4, 5, 20, 0)),
#  ('AL', datetime.datetime(2017, 3, 21, 21, 0)),
#  ('AL', datetime.datetime(2017, 3, 15, 23, 25)),
#  ('AL', datetime.datetime(2017, 3, 15, 9, 51)),
#  ('AL', datetime.datetime(2017, 3, 12, 18, 20)),
#  ('AL', datetime.datetime(2017, 3, 9, 3, 12)),
#  ('AL', datetime.datetime(2017, 3, 8, 19, 45)),
#  ('AL', datetime.datetime(2017, 3, 3, 17, 30)),
#  ('AL', datetime.datetime(2017, 2, 27, 1, 30)),
#  ('AL', datetime.datetime(2017, 2, 26, 23, 0)),
#  ('AL', datetime.datetime(2017, 2, 22, 21, 50)),
#  ('AL', datetime.datetime(2017, 2, 22, 19, 19)),
#  ('AL', datetime.datetime(2017, 2, 16, 7, 18)),
#  ('AL', datetime.datetime(2017, 2, 11, 17, 20)),
#  ('AL', datetime.datetime(2017, 2, 2, 18, 30)),
#  ('AL', datetime.datetime(2017, 1, 29, 18, 0)),
#  ('AL', datetime.datetime(2017, 1, 26, 19, 0)),
#  ('AL', datetime.datetime(2017, 1, 9, 3, 12)),
#  ('AL', datetime.datetime(2017, 1, 9, 3, 2)),
#  ('AL', datetime.datetime(2016, 12, 30, 14, 42)),
#  ('AL', datetime.datetime(2016, 12, 29, 22, 0)),
#  ('AL', datetime.datetime(2016, 12, 22, 21, 30)),
#  ('AL', datetime.datetime(2016, 12, 15, 5, 37)),
#  ('AL', datetime.datetime(2016, 12, 1, 17, 30)),
#  ('AL', datetime.datetime(2016, 11, 11, 23, 0)),
#  ('AL', datetime.datetime(2016, 11, 2, 23, 0)),
#  ('AL', datetime.datetime(2016, 11, 1, 18, 30)),
#  ('AL', datetime.datetime(2016, 10, 30, 2, 0)),
#  ('AL', datetime.datetime(2016, 10, 21, 23, 30)),
#  ('AL', datetime.datetime(2016, 10, 21, 19, 30)),
#  ('AL', datetime.datetime(2016, 10, 12, 6, 50)),
#  ('AL', datetime.datetime(2016, 10, 8, 22, 0)),
#  ('AL', datetime.datetime(2016, 10, 7, 0, 0)),
#  ('AL', datetime.datetime(2016, 10, 5, 20, 0)),
#  ('AL', datetime.datetime(2016, 9, 29, 22, 10)),
#  ('AL', datetime.datetime(2016, 9, 25, 20, 30)),
#  ('AL', datetime.datetime(2016, 9, 17, 0, 0)),
#  ('AL', datetime.datetime(2016, 9, 3, 6, 0)),
#  ('AL', datetime.datetime(2016, 8, 24, 3, 45)),
#  ('AL', datetime.datetime(2016, 8, 3, 23, 45)),
#  ('AL', datetime.datetime(2016, 8, 2, 5, 15)),
#  ('AL', datetime.datetime(2016, 7, 25, 20, 30)),
#  ('AL', datetime.datetime(2016, 7, 23, 3, 0)),
#  ('AL', datetime.datetime(2016, 7, 22, 10, 0)),
#  ('AL', datetime.datetime(2016, 7, 21, 22, 45)),
#  ('AL', datetime.datetime(2016, 7, 21, 22, 10)),
#  ('AL', datetime.datetime(2016, 7, 21, 21, 0)),
#  ('AL', datetime.datetime(2016, 7, 19, 23, 30)),
#  ('AL', datetime.datetime(2016, 7, 7, 22, 3)),
#  ('AL', datetime.datetime(2016, 7, 4, 20, 45)),
#  ('AL', datetime.datetime(2016, 7, 3, 20, 58)),
#  ('AL', datetime.datetime(2016, 7, 2, 20, 38)),
#  ('AL', datetime.datetime(2016, 7, 1, 20, 0)),
#  ('AL', datetime.datetime(2016, 7, 1, 7, 33)),
#  ('AL', datetime.datetime(2016, 6, 23, 22, 45)),
#  ('AL', datetime.datetime(2016, 6, 11, 21, 30)),
#  ('AL', datetime.datetime(2016, 6, 3, 0, 0)),
#  ('AL', datetime.datetime(2016, 5, 15, 10, 45)),
#  ('AL', datetime.datetime(2016, 3, 16, 20, 30)),
#  ('AL', datetime.datetime(2016, 3, 15, 22, 15)),
#  ('AL', datetime.datetime(2016, 3, 6, 22, 57)),
#  ('AL', datetime.datetime(2016, 2, 25, 4, 15)),
#  ('AL', datetime.datetime(2016, 2, 19, 21, 55)),
#  ('AL', datetime.datetime(2016, 2, 13, 21, 30)),
#  ('AL', datetime.datetime(2016, 2, 3, 22, 0)),
#  ('AL', datetime.datetime(2016, 1, 24, 18, 43)),
#  ('AL', datetime.datetime(2016, 1, 8, 2, 30)),
#  ('AL', datetime.datetime(2016, 1, 7, 20, 30)),
#  ('AL', datetime.datetime(2016, 1, 6, 5, 55)),
#  ('AL', datetime.datetime(2016, 1, 5, 20, 15)),
#  ('AL', datetime.datetime(2015, 12, 31, 20, 0)),
#  ('AL', datetime.datetime(2015, 12, 30, 20, 0)),
#  ('AL', datetime.datetime(2015, 12, 29, 18, 17)),
#  ('AL', datetime.datetime(2015, 12, 14, 21, 15)),
#  ('AL', datetime.datetime(2015, 12, 8, 21, 0)),
#  ('AL', datetime.datetime(2015, 12, 8, 18, 20)),
#  ('AL', datetime.datetime(2015, 12, 4, 17, 0)),
#  ('AL', datetime.datetime(2015, 11, 28, 20, 0)),
#  ('AL', datetime.datetime(2015, 11, 23, 3, 0)),
#  ('AL', datetime.datetime(2015, 11, 22, 3, 0)),
#  ('AL', datetime.datetime(2015, 11, 17, 18, 0)),
#  ('AL', datetime.datetime(2015, 11, 16, 19, 30)),
#  ('AL', datetime.datetime(2015, 11, 12, 20, 0)),
#  ('AL', datetime.datetime(2015, 11, 11, 18, 0)),
#  ('AL', datetime.datetime(2015, 11, 11, 17, 39)),
#  ('AL', datetime.datetime(2015, 11, 11, 17, 20)),
#  ('AL', datetime.datetime(2015, 11, 11, 17, 0)),
#  ('AL', datetime.datetime(2015, 11, 11, 15, 0)),
#  ('AL', datetime.datetime(2015, 11, 4, 22, 15)),
#  ('AL', datetime.datetime(2015, 11, 2, 16, 0)),
#  ('AL', datetime.datetime(2015, 10, 29, 4, 15)),
#  ('AL', datetime.datetime(2015, 10, 22, 3, 51)),
#  ('AL', datetime.datetime(2015, 10, 21, 22, 38)),
#  ('AL', datetime.datetime(2015, 10, 19, 19, 45)),
#  ('AL', datetime.datetime(2015, 10, 11, 4, 30)),
#  ('AL', datetime.datetime(2015, 10, 10, 20, 40)),
#  ('AL', datetime.datetime(2015, 10, 10, 18, 0)),
#  ('AL', datetime.datetime(2015, 9, 18, 20, 0)),
#  ('AL', datetime.datetime(2015, 9, 18, 19, 20)),
#  ('AL', datetime.datetime(2015, 9, 16, 20, 20)),
#  ('AL', datetime.datetime(2015, 9, 15, 20, 20)),
#  ('AL', datetime.datetime(2015, 9, 15, 19, 0)),
#  ('AL', datetime.datetime(2015, 9, 15, 18, 15)),
#  ('AL', datetime.datetime(2015, 9, 14, 20, 45)),
#  ('AL', datetime.datetime(2015, 9, 12, 19, 45)),
#  ('AL', datetime.datetime(2015, 9, 4, 0, 0)),
#  ('AL', datetime.datetime(2015, 9, 1, 1, 0)),
#  ('AL', datetime.datetime(2015, 8, 26, 23, 0)),
#  ('AL', datetime.datetime(2015, 8, 12, 0, 0)),
#  ('AL', datetime.datetime(2015, 8, 10, 19, 13)),
#  ('AL', datetime.datetime(2015, 8, 10, 3, 0)),
#  ('AL', datetime.datetime(2015, 7, 20, 22, 15)),
#  ('AL', datetime.datetime(2015, 7, 16, 22, 0)),
#  ('AL', datetime.datetime(2015, 7, 11, 21, 15)),
#  ('AL', datetime.datetime(2015, 7, 4, 21, 0)),
#  ('AL', datetime.datetime(2015, 7, 3, 21, 0)),
#  ('AL', datetime.datetime(2015, 6, 29, 0, 30)),
#  ('AL', datetime.datetime(2015, 6, 15, 22, 45)),
#  ('AL', datetime.datetime(2015, 6, 14, 18, 0)),
#  ('AL', datetime.datetime(2015, 6, 9, 10, 0)),
#  ('AL', datetime.datetime(2015, 6, 4, 20, 0)),
#  ('AL', datetime.datetime(2015, 5, 10, 13, 0)),
#  ('AL', datetime.datetime(2015, 5, 9, 20, 45)),
#  ('AL', datetime.datetime(2015, 4, 19, 19, 30)),
#  ('AL', datetime.datetime(2015, 4, 11, 22, 15)),
#  ('AL', datetime.datetime(2015, 2, 14, 23, 38)),
#  ('AL', datetime.datetime(2015, 1, 28, 20, 0)),
#  ('AL', datetime.datetime(2015, 1, 28, 20, 0)),
#  ('AL', datetime.datetime(2015, 1, 18, 18, 35)),
#  ('AL', datetime.datetime(2015, 1, 18, 17, 50)),
#  ('AL', datetime.datetime(2015, 1, 17, 21, 0)),
#  ('AL', datetime.datetime(2015, 1, 17, 20, 25)),
#  ('AL', datetime.datetime(2015, 1, 17, 18, 35)),
#  ('AL', datetime.datetime(2015, 1, 9, 18, 45)),
#  ('AL', datetime.datetime(2015, 1, 5, 20, 0)),
#  ('AL', datetime.datetime(2014, 12, 26, 20, 45)),
#  ('AL', datetime.datetime(2014, 12, 14, 0, 30)),
#  ('AL', datetime.datetime(2014, 12, 11, 16, 40)),
#  ('AL', datetime.datetime(2014, 12, 11, 16, 20)),
#  ('AL', datetime.datetime(2014, 12, 8, 4, 20)),
#  ('AL', datetime.datetime(2014, 12, 4, 19, 0)),
#  ('AL', datetime.datetime(2014, 11, 21, 20, 0)),
#  ('AL', datetime.datetime(2014, 11, 20, 20, 0)),
#  ('AL', datetime.datetime(2014, 11, 19, 0, 0)),
#  ('AL', datetime.datetime(2014, 11, 18, 18, 0)),
#  ('AL', datetime.datetime(2014, 11, 17, 22, 30)),
#  ('AL', datetime.datetime(2014, 11, 13, 17, 0)),
#  ('AL', datetime.datetime(2014, 11, 8, 0, 0)),
#  ('AL', datetime.datetime(2014, 11, 6, 19, 0)),
#  ('AL', datetime.datetime(2014, 11, 6, 18, 0)),
#  ('AL', datetime.datetime(2014, 11, 2, 23, 0)),
#  ('AL', datetime.datetime(2014, 10, 30, 20, 0)),
#  ('AL', datetime.datetime(2014, 10, 22, 19, 45)),
#  ('AL', datetime.datetime(2014, 10, 22, 5, 45)),
#  ('AL', datetime.datetime(2014, 10, 20, 19, 55)),
#  ('AL', datetime.datetime(2014, 10, 18, 11, 30)),
#  ('AL', datetime.datetime(2014, 10, 16, 21, 30)),
#  ('AL', datetime.datetime(2014, 10, 14, 20, 30)),
#  ('AL', datetime.datetime(2014, 10, 6, 19, 48)),
#  ('AL', datetime.datetime(2014, 9, 25, 20, 45)),
#  ('AL', datetime.datetime(2014, 9, 24, 18, 25)),
#  ('AL', datetime.datetime(2014, 9, 20, 21, 30)),
#  ('AL', datetime.datetime(2014, 9, 19, 21, 0)),
#  ('AL', datetime.datetime(2014, 9, 17, 21, 33)),
#  ('AL', datetime.datetime(2014, 9, 17, 20, 35)),
#  ('AL', datetime.datetime(2014, 9, 17, 20, 0)),
#  ('AL', datetime.datetime(2014, 9, 16, 19, 30)),
#  ('AL', datetime.datetime(2014, 9, 14, 22, 15)),
#  ('AL', datetime.datetime(2014, 9, 12, 21, 30)),
#  ('AL', datetime.datetime(2014, 9, 5, 19, 30)),
#  ('AL', datetime.datetime(2014, 8, 26, 20, 30)),
#  ('AL', datetime.datetime(2014, 8, 23, 23, 20)),
#  ('AL', datetime.datetime(2014, 8, 23, 23, 0)),
#  ('AL', datetime.datetime(2014, 8, 11, 21, 0)),
#  ('AL', datetime.datetime(2014, 8, 2, 22, 0)),
#  ('AL', datetime.datetime(2014, 7, 19, 2, 0)),
#  ('AL', datetime.datetime(2014, 7, 16, 23, 0)),
#  ('AL', datetime.datetime(2014, 7, 16, 22, 30)),
#  ('AL', datetime.datetime(2014, 7, 16, 21, 50)),
#  ('AL', datetime.datetime(2014, 7, 16, 20, 47)),
#  ('AL', datetime.datetime(2014, 7, 14, 19, 40)),
#  ('AL', datetime.datetime(2014, 7, 12, 23, 0)),
#  ('AL', datetime.datetime(2014, 7, 12, 23, 0)),
#  ('AL', datetime.datetime(2014, 7, 10, 21, 15)),
#  ('AL', datetime.datetime(2014, 7, 6, 20, 45)),
#  ('AL', datetime.datetime(2014, 7, 5, 22, 0)),
#  ('AL', datetime.datetime(2014, 7, 4, 23, 0)),
#  ('AL', datetime.datetime(2014, 7, 4, 22, 5)),
#  ('AL', datetime.datetime(2014, 7, 4, 21, 45)),
#  ('AL', datetime.datetime(2014, 7, 4, 21, 15)),
#  ('AL', datetime.datetime(2014, 7, 4, 21, 0)),
#  ('AL', datetime.datetime(2014, 7, 4, 9, 0)),
#  ('AL', datetime.datetime(2014, 7, 3, 20, 0)),
#  ('AL', datetime.datetime(2014, 6, 30, 21, 50)),
#  ('AL', datetime.datetime(2014, 6, 28, 18, 0)),
#  ('AL', datetime.datetime(2014, 6, 27, 23, 0)),
#  ('AL', datetime.datetime(2014, 6, 27, 21, 0)),
#  ('AL', datetime.datetime(2014, 6, 26, 23, 0)),
#  ('AL', datetime.datetime(2014, 6, 19, 20, 50)),
#  ('AL', datetime.datetime(2014, 6, 17, 21, 15)),
#  ('AL', datetime.datetime(2014, 6, 5, 22, 0)),
#  ('AL', datetime.datetime(2014, 6, 3, 18, 25)),
#  ('AL', datetime.datetime(2014, 5, 30, 21, 30)),
#  ('AL', datetime.datetime(2014, 5, 30, 21, 30)),
#  ('AL', datetime.datetime(2014, 5, 27, 21, 0)),
#  ('AL', datetime.datetime(2014, 5, 25, 23, 0)),
#  ('AL', datetime.datetime(2014, 5, 25, 22, 30)),
#  ('AL', datetime.datetime(2014, 5, 22, 0, 0)),
#  ('AL', datetime.datetime(2014, 5, 17, 5, 4)),
#  ('AL', datetime.datetime(2014, 5, 15, 14, 0)),
#  ('AL', datetime.datetime(2014, 5, 10, 20, 0)),
#  ('AL', datetime.datetime(2014, 5, 8, 21, 0)),
#  ('AL', datetime.datetime(2014, 5, 8, 21, 0)),
#  ('AL', datetime.datetime(2014, 5, 7, 21, 0)),
#  ('AL', datetime.datetime(2014, 5, 7, 3, 30)),
#  ('AL', datetime.datetime(2014, 5, 6, 20, 35)),
#  ('AL', datetime.datetime(2014, 5, 6, 20, 8)),
#  ('AL', datetime.datetime(2014, 5, 2, 20, 38)),
#  ('AL', datetime.datetime(2014, 5, 1, 21, 15)),
#  ('AL', datetime.datetime(2014, 5, 1, 20, 48)),
#  ('AL', datetime.datetime(2014, 5, 1, 20, 30)),
#  ('AL', datetime.datetime(2014, 5, 1, 20, 0)),
#  ('AL', datetime.datetime(2014, 5, 1, 17, 0)),
#  ('AL', datetime.datetime(2014, 4, 26, 22, 30)),
#  ('AL', datetime.datetime(2014, 4, 25, 22, 30)),
#  ('AL', datetime.datetime(2014, 4, 25, 22, 9)),
#  ('AL', datetime.datetime(2014, 4, 25, 20, 0)),
#  ('AL', datetime.datetime(2014, 4, 24, 21, 0)),
#  ('AL', datetime.datetime(2014, 4, 24, 20, 30)),
#  ('AL', datetime.datetime(2014, 4, 23, 22, 15)),
#  ('AL', datetime.datetime(2014, 4, 23, 20, 8)),
#  ('AL', datetime.datetime(2014, 4, 16, 17, 0)),
#  ('AL', datetime.datetime(2014, 4, 16, 14, 10)),
#  ('AL', datetime.datetime(2014, 4, 13, 21, 0)),
#  ('AL', datetime.datetime(2014, 4, 11, 18, 15)),
#  ('AL', datetime.datetime(2014, 4, 5, 20, 30)),
#  ('AL', datetime.datetime(2014, 4, 3, 14, 0)),
#  ('AL', datetime.datetime(2014, 3, 27, 20, 32)),
#  ('AL', datetime.datetime(2014, 3, 20, 20, 15)),
#  ('AL', datetime.datetime(2014, 3, 16, 20, 10)),
#  ('AL', datetime.datetime(2014, 3, 10, 14, 35)),
#  ('AL', datetime.datetime(2014, 3, 10, 0, 30)),
#  ('AL', datetime.datetime(2014, 3, 7, 15, 47)),
#  ('AL', datetime.datetime(2014, 3, 5, 20, 7)),
#  ('AL', datetime.datetime(2014, 2, 28, 16, 0)),
#  ('AL', datetime.datetime(2014, 2, 27, 21, 0)),
#  ('AL', datetime.datetime(2014, 2, 27, 18, 0)),
#  ('AL', datetime.datetime(2014, 2, 22, 19, 0)),
#  ('AL', datetime.datetime(2014, 2, 18, 8, 15)),
#  ('AL', datetime.datetime(2014, 2, 18, 8, 15)),
#  ('AL', datetime.datetime(2014, 2, 17, 19, 0)),
#  ('AL', datetime.datetime(2014, 2, 17, 0, 14)),
#  ('AL', datetime.datetime(2014, 2, 8, 20, 0)),
#  ('AL', datetime.datetime(2014, 2, 5, 19, 0)),
#  ('AL', datetime.datetime(2014, 1, 30, 22, 30)),
#  ('AL', datetime.datetime(2014, 1, 26, 0, 0)),
#  ('AL', datetime.datetime(2014, 1, 23, 2, 0)),
#  ('AL', datetime.datetime(2014, 1, 20, 19, 30)),
#  ('AL', datetime.datetime(2014, 1, 16, 18, 27)),
#  ('AL', datetime.datetime(2014, 1, 15, 19, 30)),
#  ('AL', datetime.datetime(2014, 1, 15, 17, 45)),
#  ('AL', datetime.datetime(2014, 1, 12, 13, 35)),
#  ('AL', datetime.datetime(2014, 1, 4, 23, 56)),
#  ('AL', datetime.datetime(2014, 1, 1, 0, 20)),
#  ('AL', datetime.datetime(2014, 1, 1, 0, 0)),
#  ('AL', datetime.datetime(2013, 12, 31, 23, 0)),
#  ('AL', datetime.datetime(2013, 12, 26, 22, 30)),
#  ('AL', datetime.datetime(2013, 12, 20, 17, 0)),
#  ('AL', datetime.datetime(2013, 12, 19, 0, 0)),
#  ('AL', datetime.datetime(2013, 12, 16, 22, 15)),
#  ('AL', datetime.datetime(2013, 12, 16, 6, 30)),
#  ('AL', datetime.datetime(2013, 12, 14, 0, 0)),
#  ('AL', datetime.datetime(2013, 12, 9, 23, 15)),
#  ('AL', datetime.datetime(2013, 12, 1, 14, 30)),
#  ('AL', datetime.datetime(2013, 11, 27, 22, 40)),
#  ('AL', datetime.datetime(2013, 11, 18, 11, 30)),
#  ('AL', datetime.datetime(2013, 11, 7, 18, 30)),
#  ('AL', datetime.datetime(2013, 11, 6, 19, 30)),
#  ('AL', datetime.datetime(2013, 11, 6, 19, 30)),
#  ('AL', datetime.datetime(2013, 11, 5, 0, 0)),
#  ('AL', datetime.datetime(2013, 11, 3, 19, 0)),
#  ('AL', datetime.datetime(2013, 10, 23, 2, 0)),
#  ('AL', datetime.datetime(2013, 10, 23, 0, 15)),
#  ('AL', datetime.datetime(2013, 10, 15, 0, 0)),
#  ('AL', datetime.datetime(2013, 10, 8, 18, 30)),
#  ('AL', datetime.datetime(2013, 10, 6, 23, 11)),
#  ('AL', datetime.datetime(2013, 10, 5, 21, 15)),
#  ('AL', datetime.datetime(2013, 10, 4, 21, 55)),
#  ('AL', datetime.datetime(2013, 10, 4, 21, 55)),
#  ('AL', datetime.datetime(2013, 9, 28, 21, 45)),
#  ('AL', datetime.datetime(2013, 9, 28, 18, 47)),
#  ('AL', datetime.datetime(2013, 9, 27, 19, 35)),
#  ('AL', datetime.datetime(2013, 9, 18, 11, 0)),
#  ('AL', datetime.datetime(2013, 9, 14, 19, 45)),
#  ('AL', datetime.datetime(2013, 9, 9, 20, 20)),
#  ('AL', datetime.datetime(2013, 9, 7, 21, 0)),
#  ('AL', datetime.datetime(2013, 9, 5, 21, 0)),
#  ('AL', datetime.datetime(2013, 8, 15, 17, 30)),
#  ('AL', datetime.datetime(2013, 8, 4, 20, 10)),
#  ('AL', datetime.datetime(2013, 8, 4, 20, 10)),
#  ('AL', datetime.datetime(2013, 8, 2, 21, 0)),
#  ('AL', datetime.datetime(2013, 8, 1, 3, 0)),
#  ('AL', datetime.datetime(2013, 7, 29, 18, 35)),
#  ('AL', datetime.datetime(2013, 7, 29, 18, 35)),
#  ('AL', datetime.datetime(2013, 7, 27, 22, 30)),
#  ('AL', datetime.datetime(2013, 7, 27, 22, 0)),
#  ('AL', datetime.datetime(2013, 7, 13, 0, 0)),
#  ('AL', datetime.datetime(2013, 7, 12, 23, 30)),
#  ('AL', datetime.datetime(2013, 7, 12, 21, 8)),
#  ('AL', datetime.datetime(2013, 7, 12, 20, 0)),
#  ('AL', datetime.datetime(2013, 7, 11, 20, 50)),
#  ('AL', datetime.datetime(2013, 7, 7, 20, 30)),
#  ('AL', datetime.datetime(2013, 7, 6, 21, 10)),
#  ('AL', datetime.datetime(2013, 7, 5, 20, 36)),
#  ('AL', datetime.datetime(2013, 7, 2, 1, 38)),
#  ('AL', datetime.datetime(2013, 7, 1, 20, 0)),
#  ('AL', datetime.datetime(2013, 6, 30, 14, 0)),
#  ('AL', datetime.datetime(2013, 6, 30, 2, 30)),
#  ('AL', datetime.datetime(2013, 6, 11, 21, 30)),
#  ('AL', datetime.datetime(2013, 6, 4, 17, 35)),
#  ('AL', datetime.datetime(2013, 6, 4, 10, 0)),
#  ('AL', datetime.datetime(2013, 6, 3, 9, 30)),
#  ('AL', datetime.datetime(2013, 5, 30, 21, 30)),
#  ('AL', datetime.datetime(2013, 5, 26, 22, 0)),
#  ('AL', datetime.datetime(2013, 5, 26, 22, 0)),
#  ('AL', datetime.datetime(2013, 5, 24, 18, 30)),
#  ('AL', datetime.datetime(2013, 5, 20, 21, 45)),
#  ('AL', datetime.datetime(2013, 5, 10, 22, 0)),
#  ('AL', datetime.datetime(2013, 5, 7, 18, 0)),
#  ('AL', datetime.datetime(2013, 4, 27, 16, 0)),
#  ('AL', datetime.datetime(2013, 4, 26, 23, 13)),
#  ('AL', datetime.datetime(2013, 4, 26, 23, 0)),
#  ('AL', datetime.datetime(2013, 4, 26, 20, 20)),
#  ('AL', datetime.datetime(2013, 4, 25, 10, 43)),
#  ('AL', datetime.datetime(2013, 4, 8, 19, 7)),
#  ('AL', datetime.datetime(2013, 3, 29, 10, 35)),
#  ('AL', datetime.datetime(2013, 3, 27, 21, 0)),
#  ('AL', datetime.datetime(2013, 3, 17, 11, 44)),
#  ('AL', datetime.datetime(2013, 3, 15, 20, 19)),
#  ('AL', datetime.datetime(2013, 3, 15, 4, 0)),
#  ('AL', datetime.datetime(2013, 3, 11, 18, 0)),
#  ('AL', datetime.datetime(2013, 3, 9, 21, 0)),
#  ('AL', datetime.datetime(2013, 3, 7, 19, 30)),
#  ('AL', datetime.datetime(2013, 2, 3, 20, 0)),
#  ('AL', datetime.datetime(2013, 2, 3, 20, 0)),
#  ('AL', datetime.datetime(2013, 1, 31, 23, 0)),
#  ('AL', datetime.datetime(2013, 1, 31, 5, 30)),
#  ('AL', datetime.datetime(2013, 1, 22, 9, 0)),
#  ('AL', datetime.datetime(2013, 1, 21, 16, 50)),
#  ('AL', datetime.datetime(2013, 1, 20, 21, 0)),
#  ('AL', datetime.datetime(2013, 1, 10, 22, 0)),
#  ('AL', datetime.datetime(2013, 1, 6, 20, 30)),
#  ('AK', datetime.datetime(2023, 2, 11, 22, 30)),
#  ('AK', datetime.datetime(2023, 2, 10, 15, 15)),
#  ('AK', datetime.datetime(2023, 1, 11, 18, 39)),
#  ('AK', datetime.datetime(2022, 12, 21, 5, 47)),
#  ('AK', datetime.datetime(2022, 12, 21, 5, 40)),
#  ('AK', datetime.datetime(2022, 12, 19, 7, 42)),
#  ('AK', datetime.datetime(2022, 9, 18, 23, 48)),
#  ('AK', datetime.datetime(2022, 8, 17, 17, 36)),
#  ('AK', datetime.datetime(2022, 7, 20, 16, 50)),
#  ('AK', datetime.datetime(2022, 7, 9, 17, 10)),
#  ('AK', datetime.datetime(2022, 4, 7, 7, 45)),
#  ('AK', datetime.datetime(2022, 3, 28, 4, 49)),
#  ('AK', datetime.datetime(2022, 3, 20, 22, 26)),
#  ('AK', datetime.datetime(2022, 3, 11, 20, 18)),
#  ('AK', datetime.datetime(2022, 1, 5, 13, 23)),
#  ('AK', datetime.datetime(2022, 1, 5, 7, 30)),
#  ('AK', datetime.datetime(2022, 1, 2, 18, 23)),
#  ('AK', datetime.datetime(2021, 11, 20, 1, 0)),
#  ('AK', datetime.datetime(2021, 10, 29, 9, 25)),
#  ('AK', datetime.datetime(2021, 10, 29, 9, 25)),
#  ('AK', datetime.datetime(2021, 9, 5, 23, 0)),
#  ('AK', datetime.datetime(2021, 3, 17, 23, 0)),
#  ('AK', datetime.datetime(2020, 11, 30, 18, 20)),
#  ('AK', datetime.datetime(2020, 11, 10, 3, 0)),
#  ('AK', datetime.datetime(2020, 10, 30, 2, 45)),
#  ('AK', datetime.datetime(2020, 10, 10, 14, 0)),
#  ('AK', datetime.datetime(2020, 10, 3, 18, 0)),
#  ('AK', datetime.datetime(2020, 9, 7, 4, 45)),
#  ('AK', datetime.datetime(2020, 9, 6, 23, 45)),
#  ('AK', datetime.datetime(2020, 8, 22, 1, 0)),
#  ('AK', datetime.datetime(2020, 8, 21, 10, 15)),
#  ('AK', datetime.datetime(2020, 8, 20, 4, 0)),
#  ('AK', datetime.datetime(2020, 8, 17, 0, 30)),
#  ('AK', datetime.datetime(2020, 4, 9, 10, 15)),
#  ('AK', datetime.datetime(2020, 3, 30, 21, 30)),
#  ('AK', datetime.datetime(2020, 3, 30, 1, 18)),
#  ('AK', datetime.datetime(2020, 3, 23, 12, 0)),
#  ('AK', datetime.datetime(2020, 3, 12, 20, 57)),
#  ('AK', datetime.datetime(2020, 3, 6, 5, 30)),
#  ('AK', datetime.datetime(2020, 2, 29, 0, 0)),
#  ('AK', datetime.datetime(2020, 2, 24, 4, 30)),
#  ('AK', datetime.datetime(2020, 2, 15, 19, 0)),
#  ('AK', datetime.datetime(2020, 1, 26, 18, 15)),
#  ('AK', datetime.datetime(2020, 1, 16, 5, 25)),
#  ('AK', datetime.datetime(2020, 1, 2, 1, 0)),
#  ('AK', datetime.datetime(2019, 12, 31, 18, 30)),
#  ('AK', datetime.datetime(2019, 12, 24, 22, 5)),
#  ('AK', datetime.datetime(2019, 12, 13, 4, 0)),
#  ('AK', datetime.datetime(2019, 11, 11, 7, 0)),
#  ('AK', datetime.datetime(2019, 10, 31, 19, 44)),
#  ('AK', datetime.datetime(2019, 10, 26, 6, 18)),
#  ('AK', datetime.datetime(2019, 10, 25, 6, 18)),
#  ('AK', datetime.datetime(2019, 10, 24, 10, 15)),
#  ('AK', datetime.datetime(2019, 9, 22, 20, 55)),
#  ('AK', datetime.datetime(2019, 9, 15, 0, 21)),
#  ('AK', datetime.datetime(2019, 8, 16, 0, 0)),
#  ('AK', datetime.datetime(2019, 8, 8, 0, 0)),
#  ('AK', datetime.datetime(2019, 8, 7, 0, 5)),
#  ('AK', datetime.datetime(2019, 8, 6, 18, 40)),
#  ('AK', datetime.datetime(2019, 7, 4, 3, 13)),
#  ('AK', datetime.datetime(2019, 6, 14, 0, 5)),
#  ('AK', datetime.datetime(2019, 3, 10, 20, 15)),
#  ('AK', datetime.datetime(2019, 3, 1, 13, 28)),
#  ('AK', datetime.datetime(2019, 2, 13, 7, 47)),
#  ('AK', datetime.datetime(2019, 1, 20, 19, 45)),
#  ('AK', datetime.datetime(2018, 11, 30, 9, 0)),
#  ('AK', datetime.datetime(2018, 11, 17, 19, 15)),
#  ('AK', datetime.datetime(2018, 11, 14, 8, 30)),
#  ('AK', datetime.datetime(2018, 10, 30, 8, 50)),
#  ('AK', datetime.datetime(2018, 10, 29, 20, 15)),
#  ('AK', datetime.datetime(2018, 10, 29, 20, 15)),
#  ('AK', datetime.datetime(2018, 10, 17, 11, 34)),
#  ('AK', datetime.datetime(2018, 9, 30, 6, 30)),
#  ('AK', datetime.datetime(2018, 9, 29, 20, 7)),
#  ('AK', datetime.datetime(2018, 7, 1, 23, 0)),
#  ('AK', datetime.datetime(2018, 6, 27, 14, 0)),
#  ('AK', datetime.datetime(2018, 6, 24, 11, 37)),
#  ('AK', datetime.datetime(2018, 5, 8, 18, 0)),
#  ('AK', datetime.datetime(2018, 4, 15, 2, 10)),
#  ('AK', datetime.datetime(2018, 4, 12, 1, 30)),
#  ('AK', datetime.datetime(2018, 4, 11, 23, 0)),
#  ('AK', datetime.datetime(2018, 4, 5, 23, 0)),
#  ('AK', datetime.datetime(2018, 4, 1, 21, 30)),
#  ('AK', datetime.datetime(2018, 3, 11, 18, 35)),
#  ('AK', datetime.datetime(2018, 3, 8, 1, 0)),
#  ('AK', datetime.datetime(2018, 1, 28, 20, 49)),
#  ('AK', datetime.datetime(2018, 1, 26, 6, 20)),
#  ('AK', datetime.datetime(2018, 1, 16, 21, 35)),
#  ('AK', datetime.datetime(2018, 1, 13, 13, 0)),
#  ('AK', datetime.datetime(2018, 1, 13, 3, 0)),
#  ('AK', datetime.datetime(2018, 1, 6, 8, 25)),
#  ('AK', datetime.datetime(2017, 12, 25, 1, 0)),
#  ('AK', datetime.datetime(2017, 12, 1, 1, 0)),
#  ('AK', datetime.datetime(2017, 10, 18, 9, 0)),
#  ('AK', datetime.datetime(2017, 10, 18, 8, 0)),
#  ('AK', datetime.datetime(2017, 10, 17, 21, 46)),
#  ('AK', datetime.datetime(2017, 10, 10, 21, 50)),
#  ('AK', datetime.datetime(2017, 7, 27, 5, 55)),
#  ('AK', datetime.datetime(2017, 5, 16, 3, 0)),
#  ('AK', datetime.datetime(2017, 5, 1, 1, 50)),
#  ('AK', datetime.datetime(2017, 3, 17, 22, 35)),
#  ('AK', datetime.datetime(2017, 3, 14, 23, 30)),
#  ('AK', datetime.datetime(2017, 3, 14, 23, 30)),
#  ('AK', datetime.datetime(2017, 3, 5, 20, 29)),
#  ('AK', datetime.datetime(2017, 3, 4, 4, 0)),
#  ('AK', datetime.datetime(2017, 3, 3, 21, 38)),
#  ('AK', datetime.datetime(2017, 3, 3, 8, 15)),
#  ('AK', datetime.datetime(2017, 2, 26, 22, 51)),
#  ('AK', datetime.datetime(2017, 2, 26, 20, 30)),
#  ('AK', datetime.datetime(2017, 2, 17, 20, 7)),
#  ('AK', datetime.datetime(2017, 1, 20, 22, 0)),
#  ('AK', datetime.datetime(2017, 1, 1, 0, 10)),
#  ('AK', datetime.datetime(2016, 12, 31, 23, 50)),
#  ('AK', datetime.datetime(2016, 12, 31, 23, 45)),
#  ('AK', datetime.datetime(2016, 12, 31, 20, 30)),
#  ('AK', datetime.datetime(2016, 12, 23, 18, 10)),
#  ('AK', datetime.datetime(2016, 12, 22, 4, 15)),
#  ('AK', datetime.datetime(2016, 12, 19, 10, 30)),
#  ('AK', datetime.datetime(2016, 12, 7, 23, 30)),
#  ('AK', datetime.datetime(2016, 11, 29, 6, 0)),
#  ('AK', datetime.datetime(2016, 11, 11, 21, 45)),
#  ('AK', datetime.datetime(2016, 11, 5, 18, 20)),
#  ('AK', datetime.datetime(2016, 10, 25, 19, 45)),
#  ('AK', datetime.datetime(2016, 10, 7, 22, 0)),
#  ('AK', datetime.datetime(2016, 10, 4, 18, 15)),
#  ('AK', datetime.datetime(2016, 9, 27, 1, 30)),
#  ('AK', datetime.datetime(2016, 9, 18, 14, 34)),
#  ('AK', datetime.datetime(2016, 9, 12, 1, 0)),
#  ('AK', datetime.datetime(2016, 9, 10, 21, 0)),
#  ('AK', datetime.datetime(2016, 8, 30, 23, 8)),
#  ('AK', datetime.datetime(2016, 8, 28, 21, 40)),
#  ('AK', datetime.datetime(2016, 8, 11, 1, 20)),
#  ('AK', datetime.datetime(2016, 7, 15, 22, 30)),
#  ('AK', datetime.datetime(2016, 6, 14, 1, 13)),
#  ('AK', datetime.datetime(2016, 6, 12, 21, 30)),
#  ('AK', datetime.datetime(2016, 6, 5, 2, 12)),
#  ('AK', datetime.datetime(2016, 5, 29, 18, 8)),
#  ('AK', datetime.datetime(2016, 5, 13, 3, 0)),
#  ('AK', datetime.datetime(2016, 4, 2, 3, 55)),
#  ('AK', datetime.datetime(2016, 3, 26, 23, 30)),
#  ('AK', datetime.datetime(2016, 3, 25, 17, 30)),
#  ('AK', datetime.datetime(2016, 3, 23, 21, 0)),
#  ('AK', datetime.datetime(2016, 3, 14, 0, 15)),
#  ('AK', datetime.datetime(2016, 3, 12, 3, 0)),
#  ('AK', datetime.datetime(2016, 3, 11, 7, 0)),
#  ('AK', datetime.datetime(2016, 2, 18, 20, 45)),
#  ('AK', datetime.datetime(2016, 2, 16, 6, 45)),
#  ('AK', datetime.datetime(2016, 2, 13, 9, 38)),
#  ('AK', datetime.datetime(2016, 2, 10, 16, 0)),
#  ('AK', datetime.datetime(2016, 2, 8, 20, 15)),
#  ('AK', datetime.datetime(2016, 2, 6, 19, 41)),
#  ('AK', datetime.datetime(2016, 1, 31, 20, 30)),
#  ('AK', datetime.datetime(2016, 1, 29, 19, 5)),
#  ('AK', datetime.datetime(2016, 1, 18, 20, 45)),
#  ('AK', datetime.datetime(2016, 1, 1, 0, 0)),
#  ('AK', datetime.datetime(2015, 12, 31, 23, 55)),
#  ('AK', datetime.datetime(2015, 12, 31, 19, 0)),
#  ('AK', datetime.datetime(2015, 12, 18, 1, 30)),
#  ('AK', datetime.datetime(2015, 12, 10, 23, 30)),
#  ('AK', datetime.datetime(2015, 11, 27, 17, 30)),
#  ('AK', datetime.datetime(2015, 11, 15, 21, 0)),
#  ('AK', datetime.datetime(2015, 11, 3, 18, 0)),
#  ('AK', datetime.datetime(2015, 11, 2, 0, 0)),
#  ('AK', datetime.datetime(2015, 11, 1, 1, 30)),
#  ('AK', datetime.datetime(2015, 11, 1, 0, 0)),
#  ('AK', datetime.datetime(2015, 9, 22, 11, 30)),
#  ('AK', datetime.datetime(2015, 9, 20, 0, 0)),
#  ('AK', datetime.datetime(2015, 8, 30, 5, 50)),
#  ('AK', datetime.datetime(2015, 8, 22, 22, 50)),
#  ('AK', datetime.datetime(2015, 8, 22, 15, 0)),
#  ('AK', datetime.datetime(2015, 8, 20, 22, 48)),
#  ('AK', datetime.datetime(2015, 8, 11, 23, 45)),
#  ('AK', datetime.datetime(2015, 8, 4, 12, 20)),
#  ('AK', datetime.datetime(2015, 7, 4, 23, 15)),
#  ('AK', datetime.datetime(2015, 6, 13, 14, 25)),
#  ('AK', datetime.datetime(2015, 5, 2, 0, 0)),
#  ('AK', datetime.datetime(2015, 4, 3, 22, 0)),
#  ('AK', datetime.datetime(2015, 4, 3, 22, 0)),
#  ('AK', datetime.datetime(2015, 3, 25, 9, 0)),
#  ('AK', datetime.datetime(2015, 3, 24, 7, 5)),
#  ('AK', datetime.datetime(2015, 3, 23, 21, 56)),
#  ('AK', datetime.datetime(2015, 3, 22, 22, 0)),
#  ('AK', datetime.datetime(2015, 3, 20, 23, 0)),
#  ('AK', datetime.datetime(2015, 3, 18, 23, 40)),
#  ('AK', datetime.datetime(2015, 3, 16, 21, 0)),
#  ('AK', datetime.datetime(2015, 3, 13, 21, 0)),
#  ('AK', datetime.datetime(2015, 3, 8, 21, 0)),
#  ('AK', datetime.datetime(2015, 3, 8, 21, 0)),
#  ('AK', datetime.datetime(2015, 3, 7, 9, 52)),
#  ('AK', datetime.datetime(2015, 3, 4, 21, 0)),
#  ('AK', datetime.datetime(2015, 2, 25, 5, 0)),
#  ('AK', datetime.datetime(2015, 1, 31, 8, 5)),
#  ('AK', datetime.datetime(2015, 1, 14, 18, 0)),
#  ('AK', datetime.datetime(2015, 1, 8, 21, 30)),
#  ('AK', datetime.datetime(2015, 1, 6, 7, 50)),
#  ('AK', datetime.datetime(2014, 12, 30, 23, 0)),
#  ('AK', datetime.datetime(2014, 12, 26, 20, 40)),
#  ('AK', datetime.datetime(2014, 12, 24, 17, 30)),
#  ('AK', datetime.datetime(2014, 12, 6, 1, 0)),
#  ('AK', datetime.datetime(2014, 11, 20, 22, 0)),
#  ('AK', datetime.datetime(2014, 11, 18, 20, 30)),
#  ('AK', datetime.datetime(2014, 10, 22, 20, 30)),
#  ('AK', datetime.datetime(2014, 9, 25, 11, 0)),
#  ('AK', datetime.datetime(2014, 9, 20, 22, 15)),
#  ('AK', datetime.datetime(2014, 9, 14, 22, 30)),
#  ('AK', datetime.datetime(2014, 9, 13, 9, 43)),
#  ('AK', datetime.datetime(2014, 8, 31, 2, 0)),
#  ('AK', datetime.datetime(2014, 8, 7, 17, 30)),
#  ('AK', datetime.datetime(2014, 8, 5, 0, 36)),
#  ('AK', datetime.datetime(2014, 6, 3, 14, 0)),
#  ('AK', datetime.datetime(2014, 5, 14, 17, 45)),
#  ('AK', datetime.datetime(2014, 5, 13, 2, 0)),
#  ('AK', datetime.datetime(2014, 5, 10, 21, 0)),
#  ('AK', datetime.datetime(2014, 5, 5, 16, 0)),
#  ('AK', datetime.datetime(2014, 4, 19, 22, 15)),
#  ('AK', datetime.datetime(2014, 4, 19, 0, 4)),
#  ('AK', datetime.datetime(2014, 4, 14, 22, 45)),
#  ('AK', datetime.datetime(2014, 4, 11, 21, 30)),
#  ('AK', datetime.datetime(2014, 4, 9, 11, 30)),
#  ('AK', datetime.datetime(2014, 4, 2, 11, 0)),
#  ('AK', datetime.datetime(2014, 3, 31, 2, 30)),
#  ('AK', datetime.datetime(2014, 3, 29, 20, 45)),
#  ('AK', datetime.datetime(2014, 3, 28, 11, 30)),
#  ('AK', datetime.datetime(2014, 3, 28, 11, 17)),
#  ('AK', datetime.datetime(2014, 3, 28, 11, 3)),
#  ('AK', datetime.datetime(2014, 3, 25, 22, 0)),
#  ('AK', datetime.datetime(2014, 3, 25, 22, 0)),
#  ('AK', datetime.datetime(2014, 3, 12, 23, 30)),
#  ('AK', datetime.datetime(2014, 3, 3, 19, 2)),
#  ('AK', datetime.datetime(2014, 3, 2, 1, 0)),
#  ('AK', datetime.datetime(2014, 3, 1, 0, 0)),
#  ('AK', datetime.datetime(2014, 2, 23, 19, 45)),
#  ('AK', datetime.datetime(2014, 2, 21, 23, 30)),
#  ('AK', datetime.datetime(2014, 2, 21, 0, 0)),
#  ('AK', datetime.datetime(2014, 2, 19, 3, 0)),
#  ('AK', datetime.datetime(2014, 1, 31, 22, 0)),
#  ('AK', datetime.datetime(2014, 1, 14, 23, 0)),
#  ('AK', datetime.datetime(2014, 1, 2, 11, 45)),
#  ('AK', datetime.datetime(2013, 12, 31, 23, 0)),
#  ('AK', datetime.datetime(2013, 12, 31, 20, 28)),
#  ('AK', datetime.datetime(2013, 12, 31, 1, 0)),
#  ('AK', datetime.datetime(2013, 12, 26, 18, 21)),
#  ('AK', datetime.datetime(2013, 12, 23, 22, 22)),
#  ('AK', datetime.datetime(2013, 12, 23, 22, 11)),
#  ('AK', datetime.datetime(2013, 12, 23, 21, 15)),
#  ('AK', datetime.datetime(2013, 12, 23, 16, 0)),
#  ('AK', datetime.datetime(2013, 12, 22, 18, 0)),
#  ('AK', datetime.datetime(2013, 12, 19, 16, 0)),
#  ('AK', datetime.datetime(2013, 12, 14, 18, 50)),
#  ('AK', datetime.datetime(2013, 12, 12, 22, 30)),
#  ('AK', datetime.datetime(2013, 12, 11, 8, 25)),
#  ('AK', datetime.datetime(2013, 12, 10, 23, 50)),
#  ('AK', datetime.datetime(2013, 12, 10, 23, 15)),
#  ('AK', datetime.datetime(2013, 12, 9, 21, 0)),
#  ('AK', datetime.datetime(2013, 12, 5, 17, 4)),
#  ('AK', datetime.datetime(2013, 11, 20, 18, 0)),
#  ('AK', datetime.datetime(2013, 11, 18, 21, 0)),
#  ('AK', datetime.datetime(2013, 11, 10, 19, 30)),
#  ('AK', datetime.datetime(2013, 11, 9, 17, 30)),
#  ('AK', datetime.datetime(2013, 11, 9, 17, 30)),
#  ('AK', datetime.datetime(2013, 11, 8, 23, 0)),
#  ('AK', datetime.datetime(2013, 11, 5, 18, 5)),
#  ('AK', datetime.datetime(2013, 11, 2, 20, 23)),
#  ('AK', datetime.datetime(2013, 10, 31, 20, 30)),
#  ('AK', datetime.datetime(2013, 10, 23, 20, 0)),
#  ('AK', datetime.datetime(2013, 10, 23, 18, 0)),
#  ('AK', datetime.datetime(2013, 10, 22, 18, 30)),
#  ('AK', datetime.datetime(2013, 10, 12, 14, 35)),
#  ('AK', datetime.datetime(2013, 10, 5, 2, 55)),
#  ('AK', datetime.datetime(2013, 10, 4, 21, 55)),
#  ('AK', datetime.datetime(2013, 10, 4, 20, 0)),
#  ('AK', datetime.datetime(2013, 9, 29, 21, 30)),
#  ('AK', datetime.datetime(2013, 9, 28, 21, 10)),
#  ('AK', datetime.datetime(2013, 9, 24, 20, 35)),
#  ('AK', datetime.datetime(2013, 9, 21, 21, 20)),
#  ('AK', datetime.datetime(2013, 9, 13, 22, 0)),
#  ('AK', datetime.datetime(2013, 9, 5, 22, 0)),
#  ('AK', datetime.datetime(2013, 8, 30, 4, 0)),
#  ('AK', datetime.datetime(2013, 8, 7, 21, 30)),
#  ('AK', datetime.datetime(2013, 7, 25, 1, 15)),
#  ('AK', datetime.datetime(2013, 7, 22, 3, 13)),
#  ('AK', datetime.datetime(2013, 6, 5, 1, 20)),
#  ('AK', datetime.datetime(2013, 3, 16, 23, 30)),
#  ('AK', datetime.datetime(2013, 3, 16, 23, 20)),
#  ('AK', datetime.datetime(2013, 3, 16, 5, 10)),
#  ('AK', datetime.datetime(2013, 3, 3, 18, 30)),
#  ('AK', datetime.datetime(2013, 3, 1, 21, 0)),
#  ('AK', datetime.datetime(2013, 2, 23, 21, 30)),
#  ('AK', datetime.datetime(2013, 1, 19, 21, 0)),
#  ('AK', datetime.datetime(2013, 1, 7, 1, 50)),
#  ('AK', datetime.datetime(2013, 1, 1, 1, 0)),
#  ('AZ', datetime.datetime(2023, 5, 16, 19, 0)),
#  ('AZ', datetime.datetime(2023, 5, 11, 4, 6)),
#  ('AZ', datetime.datetime(2023, 5, 6, 20, 20)),
#  ('AZ', datetime.datetime(2023, 5, 5, 20, 0)),
#  ('AZ', datetime.datetime(2023, 5, 3, 5, 40)),
#  ('AZ', datetime.datetime(2023, 4, 29, 20, 6)),
#  ('AZ', datetime.datetime(2023, 4, 29, 1, 0)),
#  ('AZ', datetime.datetime(2023, 4, 27, 15, 34)),
#  ('AZ', datetime.datetime(2023, 4, 23, 14, 30)),
#  ('AZ', datetime.datetime(2023, 4, 21, 19, 8)),
#  ('AZ', datetime.datetime(2023, 4, 13, 21, 2)),
#  ('AZ', datetime.datetime(2023, 4, 12, 1, 46)),
#  ('AZ', datetime.datetime(2023, 4, 9, 4, 31)),
#  ('AZ', datetime.datetime(2023, 4, 7, 18, 35)),
#  ('AZ', datetime.datetime(2023, 4, 1, 21, 1)),
#  ('AZ', datetime.datetime(2023, 3, 28, 20, 55)),
#  ('AZ', datetime.datetime(2023, 3, 26, 23, 25)),
#  ('AZ', datetime.datetime(2023, 3, 26, 21, 10)),
#  ('AZ', datetime.datetime(2023, 3, 23, 16, 0)),
#  ('AZ', datetime.datetime(2023, 3, 17, 19, 0)),
#  ('AZ', datetime.datetime(2023, 3, 8, 18, 52)),
#  ('AZ', datetime.datetime(2023, 3, 3, 18, 5)),
#  ('AZ', datetime.datetime(2023, 3, 2, 19, 29)),
#  ('AZ', datetime.datetime(2023, 2, 16, 19, 15)),
#  ('AZ', datetime.datetime(2023, 2, 13, 19, 30)),
#  ('AZ', datetime.datetime(2023, 2, 11, 11, 50)),
#  ('AZ', datetime.datetime(2023, 2, 9, 16, 0)),
#  ('AZ', datetime.datetime(2023, 1, 28, 18, 30)),
#  ('AZ', datetime.datetime(2023, 1, 19, 18, 20)),
#  ('AZ', datetime.datetime(2023, 1, 19, 6, 37)),
#  ('AZ', datetime.datetime(2023, 1, 17, 17, 23)),
#  ('AZ', datetime.datetime(2023, 1, 13, 6, 35)),
#  ('AZ', datetime.datetime(2023, 1, 12, 18, 36)),
#  ('AZ', datetime.datetime(2023, 1, 11, 18, 20)),
#  ...]

# %%
sighting_query = session.query(Ufos.state, Ufos.date_time).group_by(Ufos.state).all()
sighting_query
# Out:
# [('AK', datetime.datetime(2023, 2, 11, 22, 30)),
#  ('AL', datetime.datetime(2023, 5, 14, 21, 55)),
#  ('AR', datetime.datetime(2023, 5, 2, 16, 2)),
#  ('AZ', datetime.datetime(2023, 5, 16, 19, 0)),
#  ('CA', datetime.datetime(2023, 5, 17, 15, 30)),
#  ('CO', datetime.datetime(2023, 5, 9, 13, 17)),
#  ('CT', datetime.datetime(2023, 5, 13, 22, 59)),
#  ('DC', datetime.datetime(2023, 4, 13, 13, 50)),
#  ('DE', datetime.datetime(2023, 4, 13, 14, 20)),
#  ('FL', datetime.datetime(2023, 5, 13, 22, 17)),
#  ('GA', datetime.datetime(2023, 5, 10, 1, 33)),
#  ('HI', datetime.datetime(2023, 4, 6, 21, 32)),
#  ('IA', datetime.datetime(2023, 5, 7, 21, 15)),
#  ('ID', datetime.datetime(2023, 3, 15, 16, 10)),
#  ('IL', datetime.datetime(2023, 5, 17, 22, 14)),
#  ('IN', datetime.datetime(2023, 5, 17, 23, 20)),
#  ('KS', datetime.datetime(2023, 4, 29, 23, 20)),
#  ('KY', datetime.datetime(2023, 5, 13, 21, 45)),
#  ('LA', datetime.datetime(2023, 4, 27, 21, 50)),
#  ('MA', datetime.datetime(2023, 4, 21, 20, 43)),
#  ('MD', datetime.datetime(2023, 5, 13, 21, 53)),
#  ('ME', datetime.datetime(2023, 5, 12, 21, 4)),
#  ('MI', datetime.datetime(2023, 5, 15, 22, 30)),
#  ('MN', datetime.datetime(2023, 5, 14, 18, 4)),
#  ('MO', datetime.datetime(2023, 4, 8, 22, 52)),
#  ('MS', datetime.datetime(2023, 4, 16, 20, 45)),
#  ('MT', datetime.datetime(2023, 5, 1, 5, 0)),
#  ('NC', datetime.datetime(2023, 5, 16, 21, 20)),
#  ('ND', datetime.datetime(2023, 3, 1, 19, 46)),
#  ('NE', datetime.datetime(2023, 5, 12, 21, 15)),
#  ('NH', datetime.datetime(2023, 4, 15, 14, 50)),
#  ('NJ', datetime.datetime(2023, 5, 15, 4, 0)),
#  ('NM', datetime.datetime(2023, 5, 3, 23, 0)),
#  ('NV', datetime.datetime(2023, 5, 2, 0, 23)),
#  ('NY', datetime.datetime(2023, 5, 14, 10, 45)),
#  ('OH', datetime.datetime(2023, 5, 7, 23, 7)),
#  ('OK', datetime.datetime(2023, 5, 14, 23, 47)),
#  ('OR', datetime.datetime(2023, 5, 19, 1, 49)),
#  ('PA', datetime.datetime(2023, 5, 14, 22, 0)),
#  ('RI', datetime.datetime(2022, 12, 20, 23, 30)),
#  ('SC', datetime.datetime(2023, 5, 13, 23, 59)),
#  ('SD', datetime.datetime(2023, 4, 24, 11, 20)),
#  ('TN', datetime.datetime(2023, 5, 13, 21, 30)),
#  ('TX', datetime.datetime(2023, 5, 14, 4, 30)),
#  ('UT', datetime.datetime(2023, 5, 18, 13, 27)),
#  ('VA', datetime.datetime(2023, 5, 13, 22, 5)),
#  ('VT', datetime.datetime(2023, 4, 8, 21, 0)),
#  ('WA', datetime.datetime(2023, 5, 16, 23, 59)),
#  ('WI', datetime.datetime(2023, 5, 9, 11, 0)),
#  ('WV', datetime.datetime(2023, 5, 4, 5, 0)),
#  ('WY', datetime.datetime(2023, 5, 14, 21, 40))]

# %%
state_query = session.query(Ufos.state, Ufos.date_time).all()

state_dates_frequency = {}

for result in state_query:
    state = result[0]
    dates = result[1].year

    if state in state_dates_frequency:
        if dates in state_dates_frequency[state]:
            state_dates_frequency[state][dates] += 1
        else:
            state_dates_frequency[state][dates] = 1
    else:
        state_dates_frequency[state] = {}
    
       
state_dates_frequency
# Out:
# {'AL': {2023: 49,
#   2022: 152,
#   2021: 42,
#   2020: 126,
#   2019: 124,
#   2018: 62,
#   2017: 128,
#   2016: 102,
#   2015: 130,
#   2014: 260,
#   2013: 174},
#  'AK': {2023: 5,
#   2022: 28,
#   2021: 10,
#   2020: 46,
#   2019: 40,
#   2018: 52,
#   2017: 42,
#   2016: 86,
#   2015: 80,
#   2014: 86,
#   2013: 106},
#  'AZ': {2023: 79,
#   2022: 292,
#   2021: 268,
#   2020: 452,
#   2019: 464,
#   2018: 184,
#   2017: 418,
#   2016: 480,
#   2015: 570,
#   2014: 604,
#   2013: 470},
#  'AR': {2023: 23,
#   2022: 98,
#   2021: 92,
#   2020: 190,
#   2019: 148,
#   2018: 80,
#   2017: 98,
#   2016: 84,
#   2015: 86,
#   2014: 70,
#   2013: 112},
#  'CA': {2023: 243,
#   2022: 856,
#   2021: 708,
#   2020: 1266,
#   2019: 1046,
#   2018: 668,
#   2017: 1196,
#   2016: 1164,
#   2015: 1646,
#   2014: 1738,
#   2013: 1460},
#  'CO': {2023: 63,
#   2022: 232,
#   2021: 258,
#   2020: 452,
#   2019: 264,
#   2018: 224,
#   2017: 324,
#   2016: 404,
#   2015: 330,
#   2014: 400,
#   2013: 292},
#  'CT': {2023: 35,
#   2022: 138,
#   2021: 154,
#   2020: 262,
#   2019: 252,
#   2018: 220,
#   2017: 168,
#   2016: 150,
#   2015: 170,
#   2014: 194,
#   2013: 282},
#  'DE': {2023: 5,
#   2022: 48,
#   2021: 18,
#   2020: 54,
#   2019: 32,
#   2018: 16,
#   2017: 44,
#   2016: 40,
#   2015: 62,
#   2014: 74,
#   2013: 24},
#  'DC': {2023: 5,
#   2022: 10,
#   2021: 10,
#   2020: 4,
#   2019: 2,
#   2018: 6,
#   2017: 4,
#   2016: 10,
#   2015: 6,
#   2014: 14,
#   2013: 4},
#  'FL': {2023: 215,
#   2022: 668,
#   2021: 462,
#   2020: 822,
#   2019: 830,
#   2018: 462,
#   2017: 670,
#   2016: 730,
#   2015: 952,
#   2014: 1292,
#   2013: 1088},
#  'GA': {2023: 53,
#   2022: 176,
#   2021: 162,
#   2020: 264,
#   2019: 322,
#   2018: 148,
#   2017: 244,
#   2016: 246,
#   2015: 278,
#   2014: 454,
#   2013: 286},
#  'HI': {2023: 11,
#   2022: 36,
#   2021: 18,
#   2020: 94,
#   2019: 98,
#   2018: 24,
#   2017: 32,
#   2016: 58,
#   2015: 54,
#   2014: 140,
#   2013: 106},
#  'ID': {2023: 13,
#   2022: 96,
#   2021: 118,
#   2020: 256,
#   2019: 212,
#   2018: 92,
#   2017: 100,
#   2016: 150,
#   2015: 196,
#   2014: 178,
#   2013: 206},
#  'IL': {2023: 61,
#   2022: 202,
#   2021: 154,
#   2020: 344,
#   2019: 334,
#   2018: 208,
#   2017: 186,
#   2016: 312,
#   2015: 366,
#   2014: 348,
#   2013: 344},
#  'IN': {2023: 33,
#   2022: 184,
#   2021: 188,
#   2020: 396,
#   2019: 368,
#   2018: 184,
#   2017: 114,
#   2016: 174,
#   2015: 164,
#   2014: 314,
#   2013: 292},
#  'IA': {2023: 13,
#   2022: 62,
#   2021: 48,
#   2020: 146,
#   2019: 90,
#   2018: 66,
#   2017: 90,
#   2016: 82,
#   2015: 96,
#   2014: 138,
#   2013: 162},
#  'KS': {2023: 13,
#   2022: 68,
#   2021: 50,
#   2020: 144,
#   2019: 86,
#   2018: 62,
#   2017: 102,
#   2016: 98,
#   2015: 94,
#   2014: 140,
#   2013: 110},
#  'KY': {2023: 21,
#   2022: 116,
#   2021: 92,
#   2020: 180,
#   2019: 152,
#   2018: 96,
#   2017: 134,
#   2016: 108,
#   2015: 144,
#   2014: 184,
#   2013: 196},
#  'LA': {2023: 31,
#   2022: 62,
#   2021: 48,
#   2020: 88,
#   2019: 92,
#   2018: 54,
#   2017: 68,
#   2016: 96,
#   2015: 122,
#   2014: 222,
#   2013: 102},
#  'ME': {2023: 13,
#   2022: 82,
#   2021: 64,
#   2020: 152,
#   2019: 112,
#   2018: 54,
#   2017: 72,
#   2016: 142,
#   2015: 116,
#   2014: 104,
#   2013: 164},
#  'MD': {2023: 49,
#   2022: 122,
#   2021: 84,
#   2020: 166,
#   2019: 142,
#   2018: 108,
#   2017: 190,
#   2016: 196,
#   2015: 228,
#   2014: 296,
#   2013: 230},
#  'MA': {2023: 51,
#   2022: 198,
#   2021: 146,
#   2020: 282,
#   2019: 236,
#   2018: 140,
#   2017: 200,
#   2016: 236,
#   2015: 296,
#   2014: 402,
#   2013: 392},
#  'MI': {2023: 79,
#   2022: 196,
#   2021: 130,
#   2020: 366,
#   2019: 274,
#   2018: 124,
#   2017: 268,
#   2016: 272,
#   2015: 378,
#   2014: 368,
#   2013: 378},
#  'MN': {2023: 29,
#   2022: 142,
#   2021: 92,
#   2020: 240,
#   2019: 254,
#   2018: 106,
#   2017: 166,
#   2016: 170,
#   2015: 304,
#   2014: 208,
#   2013: 252},
#  'MS': {2023: 15,
#   2022: 42,
#   2021: 34,
#   2020: 54,
#   2019: 66,
#   2018: 48,
#   2017: 50,
#   2016: 64,
#   2015: 82,
#   2014: 88,
#   2013: 80},
#  'MO': {2023: 39,
#   2022: 174,
#   2021: 156,
#   2020: 262,
#   2019: 254,
#   2018: 124,
#   2017: 224,
#   2016: 224,
#   2015: 202,
#   2014: 292,
#   2013: 226},
#  'MT': {2023: 3,
#   2022: 66,
#   2021: 12,
#   2020: 112,
#   2019: 122,
#   2018: 62,
#   2017: 100,
#   2016: 98,
#   2015: 120,
#   2014: 112,
#   2013: 104},
#  'NE': {2023: 13,
#   2022: 32,
#   2021: 30,
#   2020: 68,
#   2019: 62,
#   2018: 42,
#   2017: 50,
#   2016: 32,
#   2015: 46,
#   2014: 52,
#   2013: 58},
#  'NV': {2023: 19,
#   2022: 90,
#   2021: 74,
#   2020: 190,
#   2019: 138,
#   2018: 116,
#   2017: 116,
#   2016: 128,
#   2015: 224,
#   2014: 196,
#   2013: 106},
#  'NH': {2023: 23,
#   2022: 90,
#   2021: 64,
#   2020: 176,
#   2019: 156,
#   2018: 76,
#   2017: 108,
#   2016: 106,
#   2015: 174,
#   2014: 192,
#   2013: 132},
#  'NJ': {2023: 41,
#   2022: 192,
#   2021: 154,
#   2020: 290,
#   2019: 388,
#   2018: 118,
#   2017: 242,
#   2016: 260,
#   2015: 264,
#   2014: 336,
#   2013: 334},
#  'NM': {2023: 29,
#   2022: 108,
#   2021: 100,
#   2020: 164,
#   2019: 178,
#   2018: 120,
#   2017: 166,
#   2016: 156,
#   2015: 156,
#   2014: 220,
#   2013: 178},
#  'NY': {2023: 93,
#   2022: 412,
#   2021: 394,
#   2020: 588,
#   2019: 386,
#   2018: 240,
#   2017: 374,
#   2016: 440,
#   2015: 604,
#   2014: 668,
#   2013: 524},
#  'NC': {2023: 73,
#   2022: 288,
#   2021: 200,
#   2020: 276,
#   2019: 330,
#   2018: 220,
#   2017: 292,
#   2016: 440,
#   2015: 374,
#   2014: 564,
#   2013: 398},
#  'ND': {2023: 5,
#   2022: 6,
#   2021: 18,
#   2020: 50,
#   2019: 36,
#   2018: 16,
#   2017: 18,
#   2016: 24,
#   2015: 22,
#   2014: 22,
#   2013: 14},
#  'OH': {2023: 85,
#   2022: 286,
#   2021: 214,
#   2020: 490,
#   2019: 426,
#   2018: 218,
#   2017: 304,
#   2016: 314,
#   2015: 430,
#   2014: 558,
#   2013: 728},
#  'OK': {2023: 23,
#   2022: 104,
#   2021: 68,
#   2020: 186,
#   2019: 134,
#   2018: 88,
#   2017: 104,
#   2016: 90,
#   2015: 150,
#   2014: 188,
#   2013: 162},
#  'OR': {2023: 71,
#   2022: 206,
#   2021: 194,
#   2020: 482,
#   2019: 268,
#   2018: 200,
#   2017: 254,
#   2016: 338,
#   2015: 430,
#   2014: 456,
#   2013: 378},
#  'PA': {2023: 91,
#   2022: 434,
#   2021: 286,
#   2020: 638,
#   2019: 474,
#   2018: 190,
#   2017: 358,
#   2016: 406,
#   2015: 490,
#   2014: 764,
#   2013: 616},
#  'RI': {2022: 33,
#   2021: 30,
#   2020: 54,
#   2019: 66,
#   2018: 38,
#   2017: 58,
#   2016: 68,
#   2015: 98,
#   2014: 76,
#   2013: 74},
#  'SC': {2023: 45,
#   2022: 142,
#   2021: 90,
#   2020: 236,
#   2019: 230,
#   2018: 156,
#   2017: 220,
#   2016: 194,
#   2015: 218,
#   2014: 520,
#   2013: 318},
#  'SD': {2023: 5,
#   2022: 42,
#   2021: 14,
#   2020: 32,
#   2019: 30,
#   2018: 22,
#   2017: 36,
#   2016: 46,
#   2015: 34,
#   2014: 42,
#   2013: 40},
#  'TN': {2023: 41,
#   2022: 200,
#   2021: 106,
#   2020: 216,
#   2019: 260,
#   2018: 98,
#   2017: 188,
#   2016: 228,
#   2015: 220,
#   2014: 300,
#   2013: 250},
#  'TX': {2023: 91,
#   2022: 392,
#   2021: 290,
#   2020: 614,
#   2019: 488,
#   2018: 188,
#   2017: 256,
#   2016: 318,
#   2015: 376,
#   2014: 620,
#   2013: 500},
#  'UT': {2023: 21,
#   2022: 90,
#   2021: 72,
#   2020: 220,
#   2019: 162,
#   2018: 120,
#   2017: 148,
#   2016: 184,
#   2015: 156,
#   2014: 158,
#   2013: 188},
#  'VT': {2023: 11,
#   2022: 44,
#   2021: 36,
#   2020: 70,
#   2019: 46,
#   2018: 44,
#   2017: 40,
#   2016: 46,
#   2015: 94,
#   2014: 76,
#   2013: 132},
#  'VA': {2023: 67,
#   2022: 164,
#   2021: 132,
#   2020: 218,
#   2019: 392,
#   2018: 148,
#   2017: 208,
#   2016: 242,
#   2015: 304,
#   2014: 370,
#   2013: 410},
#  'WA': {2023: 109,
#   2022: 364,
#   2021: 400,
#   2020: 750,
#   2019: 486,
#   2018: 348,
#   2017: 416,
#   2016: 458,
#   2015: 550,
#   2014: 748,
#   2013: 642},
#  'WV': {2023: 15,
#   2022: 66,
#   2021: 36,
#   2020: 96,
#   2019: 80,
#   2018: 30,
#   2017: 46,
#   2016: 64,
#   2015: 110,
#   2014: 126,
#   2013: 116},
#  'WI': {2023: 29,
#   2022: 146,
#   2021: 78,
#   2020: 276,
#   2019: 272,
#   2018: 84,
#   2017: 178,
#   2016: 242,
#   2015: 262,
#   2014: 294,
#   2013: 358},
#  'WY': {2023: 9,
#   2022: 30,
#   2021: 8,
#   2020: 54,
#   2019: 42,
#   2018: 30,
#   2017: 38,
#   2016: 32,
#   2015: 40,
#   2014: 42,
#   2013: 36}}

# %%
session.close()
